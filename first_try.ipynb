# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

drive_path = Path("/content/drive/MyDrive")

print(list(drive_path.iterdir()))
# Out:
# [PosixPath('/content/drive/MyDrive/Getting started.pdf'), PosixPath('/content/drive/MyDrive/New Release Form for SPF.pdf'), PosixPath('/content/drive/MyDrive/IMG_2167 copy.jpg'), PosixPath('/content/drive/MyDrive/Sandra’s Cv revamped.docx'), PosixPath('/content/drive/MyDrive/Copy1-NEW ACCOUNT OPENING FORM WITH CRS -INDIVIDUAL (1) (1).pdf'), PosixPath('/content/drive/MyDrive/Copy2-Reference Form.pdf'), PosixPath('/content/drive/MyDrive/Copy-Reference Form.pdf'), PosixPath('/content/drive/MyDrive/Account opening.pdf'), PosixPath('/content/drive/MyDrive/Acc opening  (1).pdf'), PosixPath('/content/drive/MyDrive/Acc opening .pdf'), PosixPath('/content/drive/MyDrive/Account opening .pdf'), PosixPath('/content/drive/MyDrive/Oh well'), PosixPath('/content/drive/MyDrive/TO-DO LIST.gdoc'), PosixPath("/content/drive/MyDrive/Uchime Ogochukwu's CV (3).docx"), PosixPath("/content/drive/MyDrive/Uchime Ogochukwu's CV (1) (1).docx"), PosixPath('/content/drive/MyDrive/Cover letter (1).docx'), PosixPat
# ...

# %%
zip_path=drive_path/"ML_Datasets "/"first_try.zip"
print(zip_path.exists())
# Out:
# True

# %%
import zipfile

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall("/content/")
first_try=Path("/content/first_try")

# %%
print(list(first_try.iterdir()))
# Out:
# [PosixPath('/content/first_try/License-Plate-Recognition-13'), PosixPath('/content/first_try/further_check.py'), PosixPath('/content/first_try/.git'), PosixPath('/content/first_try/check.py'), PosixPath('/content/first_try/data.yaml'), PosixPath('/content/first_try/.gitignore'), PosixPath('/content/first_try/.DS_Store')]

# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data="/content/first_try/data.yaml",
    epochs=1,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !git clone https://github.com/sandrauchime63/object_detection.git
# Out:
# Cloning into 'object_detection'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 7), reused 26 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 5.08 KiB | 5.08 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import userdata

token = userdata.get('githubaccesstoken')

# %%
# !find /content -name "*.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/first_try.ipynb

# %%
# !git config --global user.name "Sandra Uchime"
# !git config --global user.email "ogochukwuuchime@gmail.com"
